# %% [markdown]
# # Topography ray tracing and distance estimation

# %% [markdown]
# In this work we create a python script able to get a volcano topography, convert it to local dimensions, locate a observation point, ray trace the target and estimate the crosing distance. This was based on the master work of Alejandra Vesga-Ramírez coded in MATLAB.
#
# https://www.annalsofgeophysics.eu/index.php/annals/article/view/8353
#
# Steps followed by A. Vesga-Ramirez:
#
# 1. Descarga archivos.hgt a partir del modelo digital de elevación de la NASA STRM1 correspondiente a una resolución de 90mX90m imágenes de la NASA con resolución 90mX90m y vuelve las coordenadas latitud y longitud en vectores con una matriz de valores de elevación.
# 2. Permite seleccionar el área de trabajo y graficar en 3D.
# 3. Redefine el sistema de referencia (grados decimales) a un sistema de referencia local (metros) mediante un factor de conversión de grados a metros.
# 4. Se interpola la altura a partir de la definición de un punto de observación en 2D, con base a los datos del modelo digital de elevación NASA y se ubica este punto de observación sobre la topografía.
# 5. Se trazan líneas que atraviesan la topografía a partir de este punto se observación 3D , variando el ángulo azimutal y horizontal. Para esto, se define la variación ángulo azimut medido desde el eje X, se define la variación del ángulo cenit.
# 6. Se calculan finalmente las distancias recorridas en roca por cada dirección del muon, considerando en detalle la topografía alrededor de cada volcán que está disponible en el modelo de elevación digital global de la Tierra en NASA Shuttle Radar Topography Mission (SRTM) 1, con resolución SRTM3 90m×90m.

# %% [markdown]
# ## Topography data import

# %% [markdown]
# To upload the topography data we use the python module:
#
# https://pypi.org/project/python-srtm/
#
# Module installation
#
# !pip3.9 install python-srtm
#
# Data were donwnloaded from:
#
# https://opendap.cr.usgs.gov/opendap/hyrax/DP133/SRTM/SRTMGL1.003/2000.02.11/contents.html
#
# https://e4ftl01.cr.usgs.gov/MEASURES/SRTMGL1.003/2000.02.11/SRTMGL1_page_1.html
#
# http://step.esa.int/auxdata/dem/SRTMGL1/?C=N;O=D
#
#
# Upload data:
#
# rsync -avh SRTM_file  penaj@jupyter.redclara.net:/home/penaj/Python3.8/SRTM1
# pass: l4c0ng4*2t3032i

# %%
# !export SRTM1_DIR=/home/penaj/Python3.8/SRTM1
# !export SRTM3_DIR=/home/penaj/Python3.8/SRTM3
# %env SRTM1_DIR=/home/penaj/Python3.8/SRTM1
# %env SRTM3_DIR=/home/penaj/Python3.8/SRTM3
# Out:
# env: SRTM1_DIR=/home/penaj/Python3.8/SRTM1
# env: SRTM3_DIR=/home/penaj/Python3.8/SRTM3

# %%
# SRTM1 - 30m resolution
from srtm import Srtm1HeightMapCollection
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from scipy.optimize import curve_fit
from mpl_toolkits import mplot3d
import pyproj
import sys
from mpl_toolkits.basemap import Basemap

# %%
def progressbar(it, prefix="", size=60, file=sys.stdout):
    
    # Progress bar animation
    count = len(it)
    def show(j):
        x = int(size*j/count)
        file.write("%s[%s%s] %i/%i\r" % (prefix, "#"*x, "."*(size-x), j*100/count, 100))
        file.flush()        
    show(0)
    for i, item in enumerate(it):
        yield item
        show(i+1)
    file.write("\n")
    file.flush()

# %%
def line_eq (x, a, b):
    y = a*x + b
    return y

# %%
def ray_tracing(R, Max_Ele, D_azim, cenith, azimuth, Po_x, Po_y, Po_Ele, Po_Lat, Po_Log, Latitudes, Longitudes):
    
    # Estimation of the sky projection
    

    theta = Max_Ele - cenith # radians
    phi = D_azim + azimuth

    a = R*np.cos(phi)*np.cos(theta)
    b = R*np.sin(phi)*np.cos(theta)
    c = R*np.sin(theta)*1000

    Ps_x = Po_x + a
    Ps_y = Po_y + b
    Ps_z = Po_Ele + c

#    print ("Projected point a = %f, b = %f, c = %f" % (Ps_x, Ps_y, Ps_z))

    Px = [Po_x, Ps_x ]
    Py = [Po_y, Ps_y]
    Pz = [Po_Ele, Ps_z]
    
    Long_0 = min(Longitudes)
    Lat_0 = min(Latitudes)

    # XY ray projection, line equation extraction and generation of XY point for extraction elevation profiles

    # fit curve
    popt, ppam = curve_fit(line_eq, Px, Py)

    N = 1000 # number of evaluation points

    X_p = np.linspace(Po_x, Ps_x, N)
    Y_p = popt[0]*X_p + popt[1]
    
    # Convert XY coordinates to Lat and Long for elevation evaluation

    R_earth = 6371.0 # km

    Ps_Lat  = Lat_0  - (Ps_y / R_earth) * (180.0 / np.pi)
    Ps_Log = Long_0 - (Ps_x / R_earth) * (180.0 / np.pi) / np.cos(Po_Lat * np.pi/180.0)

    P_Lat = [Po_Lat, Ps_Lat ]
    P_Log = [Po_Log, Ps_Log]

#    print ("Projection Lat : %f and Long : %f" % (Ps_Lat, Ps_Log))
    
    # fit curve
    popt, ppam = curve_fit(line_eq, P_Log, P_Lat)

    N = 1000 # number of evaluation points

    Log_p = np.linspace(Po_Log, Ps_Log, N)
    Lat_p = popt[0]*Log_p + popt[1]

    # Get elevation profile

    Profile = np.zeros(N)

    for i in range(N):
            Profile[i] = srtm1_data.get_altitude(latitude=Lat_p[i], longitude=Log_p[i])

            
    X_p2 = np.zeros(N)
    Y_p2 = np.zeros(N)

    for i in range(N):

        X_p2[i] = Ce*(Long_0-Log_p[i])*np.cos((Lat_0+Lat_p[i])*np.pi/180.0)/360.0
        Y_p2[i] = Ce*(Lat_0-Lat_p[i])/360.0
    

    # Compute traverssing distance
    
    M = len(X_p2)
    x_fit = np.linspace(Po_x, Ps_x, M)


    # fit curve
    popt, ppam = curve_fit(line_eq, [Po_x, Ps_x], [Po_Ele, Ps_z])

    y_fit = popt[0]*x_fit + popt[1]
    
    index = []

    for i in range(M):
        if y_fit[i] < Profile[i]:
            index.append(i)
    
    if index == []: # If the projected ray is outside the target
        distance = 0
    else:
        distance = X_p2[index[-1]] - X_p2[index[0]]
    
           
    return distance, Px, Py, Pz

# %%
srtm1_data = Srtm1HeightMapCollection()
srtm1_data.build_file_index()

# %% [markdown]
# ## Import topography

# %%
M = 100 # Resolution

Lat_up = 35.410034 # Monte Fuji
Lat_low = 35.322267
Log_up = 138.775231
Log_low = 138.693145

# Sites

Latitudes = np.linspace(Lat_low, Lat_up, M) 
Longitudes = np.linspace(Log_low, Log_up, M)

Elevations = np.zeros((M,M))

for i in range(M):
    for j in range(M):
        Elevations[i,j]= srtm1_data.get_altitude(latitude=Latitudes[i], longitude=Longitudes[j])

# %% [markdown]
# ## Convert to meters

# %% [markdown]
# For converting Latitude and Longitude coordinates to cartesian coordinates, we used the following equations:
#
# $$x = C_e*(Long_0-Long_i)* \frac{\pi * \cos (Lat_0+Lat_i)*360}{180}$$
# $$y = C_e*\frac{(Lat_0-Lat_i)}{360}$$
# where $Long_0$ and $Lat_0$ are the longitude and latitude of the reference point, $C_e$ is the Earth circunference
#
# https://www.movable-type.co.uk/scripts/latlong.html

# %%
import math

Ce = 40075 # Earth circunference km
X_meter = np.zeros(M)
Y_meter = np.zeros(M)

Long_0 = min(Longitudes)
Lat_0 = min(Latitudes)

for i in range(M):
    
    X_meter[i] = Ce*(Long_0-Longitudes[i])*np.cos((Lat_0+Latitudes[i])*np.pi/180.0)/360.0 # Lenght Longitud
    Y_meter[i] = Ce*(Lat_0-Latitudes[i])/360.0 # Lenght Latitude

# %% [markdown]
# ## Locate observation point in topography

# %% [markdown]
# In this section we set the coordinates of the observation point.

# %%
Po_Log1 = 138.757963 # Fuji P1
Po_Lat1 = 35.365945

Po_Log2 = 138.751963 # Fuji P2
Po_Lat2 = 35.385945

Po_Log3 = 138.757963 # Fuji P3
Po_Lat3 = 35.343545

Po_Log4 = 138.753963 # Fuji P4
Po_Lat4 = 35.353745

Po_Log = Po_Log4
Po_Lat = Po_Lat4

Pos_Log = [Po_Log1, Po_Log2, Po_Log3, Po_Log4]
Pos_Lat = [Po_Lat1, Po_Lat2, Po_Lat3, Po_Lat4]

Po_Ele = srtm1_data.get_altitude(latitude = Po_Lat, longitude = Po_Log)
    
Po_x = Ce*(Long_0 - Po_Log)*np.cos((Lat_0 + Po_Lat)*np.pi/180.0)/360.0
Po_y = Ce*(Lat_0 - Po_Lat)/360.0

print ("Observation point elevation = %.2f m" % Po_Ele)
# Out:
# Observation point elevation = 2692.00 m

# %%
# Global and local coordinates comparison

fig = plt.figure(figsize=(14,18))
ax = fig.add_subplot(121, projection='3d')
X, Y = np.meshgrid(Longitudes, Latitudes)
Z = Elevations.reshape(X.shape)

ax.plot_surface(X, Y, Z, alpha=0.3)
ax.plot(Po_Log, Po_Lat, Po_Ele,'or')

ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
ax.set_zlabel('Elevation')

ax1 = fig.add_subplot(122, projection='3d')
Xm, Ym = np.meshgrid(X_meter, Y_meter)
Zm = Elevations.reshape(Xm.shape)

ax1.plot_surface(Xm, Ym, Elevations, alpha=0.3)
ax1.plot(Po_x, Po_y, Po_Ele, 'or')

ax1.set_xlabel('X [km]')
ax1.set_ylabel('Y [km]')
ax1.set_zlabel('Elevation [m a.s.l]')
# Out:
# Text(0.5, 0, 'Elevation [m a.s.l]')

# %% [markdown]
# ## Ray tracing

# %% [markdown]
# In this section we generate the ray tracing along the volcano structure. We define the azimuth angle $\phi$, cenith angle $\theta$, projection distance $R$ and the projected point coordinates (a,b,c)

# %%
# Highest point of the dome as a reference for pointing the telescope

# Pp_Log = -78.436714 # Cotopaxi
# Pp_Lat = -0.683556

Pp_Log = 138.731615 # Fuji
Pp_Lat = 35.363165

# Pp_Log = -75.38788 # Machin
# Pp_Lat = 4.487717

# Pp_Log = -61.181387 # Soufriere
# Pp_Lat = 13.333327

Pp_Ele = srtm1_data.get_altitude(latitude=Pp_Lat, longitude=Pp_Log)

Pp_x = Ce*(Long_0-Pp_Log)*np.cos((Lat_0+Pp_Lat)*np.pi/180.0)/360.0
Pp_y = Ce*(Lat_0-Pp_Lat)/360.0


print ("Observation point x = %f, y = %f, z = %f" % (Po_x, Po_y, Po_Ele))
print ("Projected point a = %f, b = %f, c = %f" % (Pp_x, Pp_y, Pp_Ele))
# Out:
# Observation point x = -2.240332, y = -3.504113, z = 2692.000000
# Projected point a = -1.416442, b = -4.552743, c = 3553.000000

# %%
# Two dimensional distance to the projected point
Dpp = 1000*np.sqrt((Pp_x-Po_x)**2+(Pp_y-Po_y)**2)

# Define maximum elevation angle

Max_Ele = np.arctan((Pp_Ele-Po_Ele)/Dpp)
D_azim = np.arctan((Pp_y-Po_y)/(Pp_x-Po_x))

print ("Distance to the interest point %f m" % Dpp)                
print ("Maximum elevation angle %fº" % (Max_Ele*180/np.pi))
print ("Azimuth difference %fº" % (D_azim*180/np.pi))
# Out:
# Distance to the interest point 1333.573441 m
# Maximum elevation angle 32.847651º
# Azimuth difference -51.843880º

# %% [markdown]
# ## Traversing distance matrix

# %% [markdown]
# Here we estimate the traversing distance inside the target for each trajectory defined by the stepping of azimuth and cenith angles.

# %%
R = 4 # km

Np = 50 # Number of horizontal/vertical pixels
azi = [-1.0, 1.0] # View window
cen = [-0.5, 0.3]

azimuth = np.linspace(azi[0],azi[1],Np) # Angular stepping
cenith = np.linspace(cen[0],cen[1],Np) # -0.2, 0.2

trav_distance = np.zeros((Np, Np))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(Xm, Ym, Elevations, alpha=0.3)
ax.plot(Po_x, Po_y, Po_Ele, 'or')

for i in progressbar(range(Np), "Ray tracing: ", 50): # Traversing lenght estimation
    for j in range(Np):
        
        trav_distance[i,j], Px, Py, Pz = ray_tracing(R, Max_Ele, D_azim, cenith[i], azimuth[j], Po_x, Po_y, Po_Ele, Po_Lat, Po_Log, Latitudes, Longitudes)
        ax.plot(Px, Py, Pz, 'k', alpha=0.2)

ax.set_xlabel('X [km]', fontsize=15)
ax.set_ylabel('Y [km]', fontsize=15)
ax.set_zlabel('Elevation [m a.s.l]', fontsize=15)
plt.show()
# Out:
# Ray tracing: [..................................................] 0/100
# /home/penaj/.local/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Ray tracing: [##################################################] 100/100

# %%
from matplotlib.ticker import MaxNLocator

fig = plt.figure(figsize=(25, 20))
ax = fig.add_subplot(311)
ax.set_xlabel("$\Theta_x$ [rad]", fontsize = 25)
ax.set_ylabel("$\Theta_y$ [rad]", fontsize = 25)

ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.yaxis.set_major_locator(MaxNLocator(integer=True))


extent = (azi[0],azi[1],cen[0],cen[1])
im = plt.imshow(trav_distance, interpolation='nearest', extent=extent, origin='upper')

#ax.xaxis.tick_top()

# Color bar
clb = plt.colorbar()
clb.set_label('d [km]', fontsize = 25)
clb.ax.tick_params(labelsize = 20)

# center location
plt.axvline(x=0, color='k', lw=1, linestyle='--')
plt.axhline(y=0, color='k', lw=1, linestyle='--')


# Increase tick labels
ax.tick_params(axis='both', which='major', labelsize=15)

# plt.savefig('figures/Fuji_P4.eps', format='eps', bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ## Saving data

# %% [markdown]
# In this step, we save the data of the traversing distance matrix within a metadata where the coordinates of the observation point, view point, and volcano area are specified.

# %%
# f = open("data/Fuji_P4.dat", "w")
# f.write("# Op %f %f %f \n" % (Po_Lat, Po_Log, Po_Ele)) # Observation point Lat, Long, Alt
# f.write("# Pp %f %f %f \n" % (Pp_Lat, Pp_Log, Pp_Ele))
# f.write("# A %f %f %f %f \n" % (Lat_up, Lat_low, Log_up, Log_low))
# f.write("# cenith[rad] azimuth[rad] distance[km] \n")

# for i in range(Np):
#     for j in range(Np):
#         f.write("%f %f %f \n" % (cenith[i], azimuth[j], trav_distance[i,j])) 
# f.close

# %% [markdown]
# ## Points location

# %%
# 1. Draw the map background

fig = plt.figure(figsize=(8, 10))

map = Basemap(llcrnrlon=138.6, llcrnrlat=35.2, urcrnrlon=138.9, urcrnrlat=35.5, epsg=4269)
#http://server.arcgisonline.com/arcgis/rest/services
#EPSG Number of America is 4269

map.arcgisimage(service='ESRI_Imagery_World_2D', xpixels = 2000) # World_Physical_Map
map.scatter(Pp_Log, Pp_Lat, latlon=True, color='r', label='Top')
sc = map.scatter(Pos_Log, Pos_Lat, latlon=True, c='w', label='Observation points')
plt.text(Pp_Log-0.1, Pp_Lat+0.1, "Mount Fuji", color="w", fontsize=20)
plt.legend(loc=3)

plt.show()
# Out:
# /home/penaj/.local/lib/python3.9/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# ## Loading data and plotting

# %%
data = np.loadtxt('data/Fuji_P1.dat', comments = '#')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_120024/3676943128.py in <module>
# ----> 1 data = np.loadtxt('data/Fuji_P1.dat', comments = '#')
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1146         # converting the data
#    1147         X = None
# -> 1148         for x in read_data(_loadtxt_chunksize):
#    1149             if X is None:
#    1150                 X = np.array(x, dtype)
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#     993             if len(vals) != N:
#     994                 line_num = i + skiprows + 1
# --> 995                 raise ValueError("Wrong number of columns at line %d"
#     996                                  % line_num)
#     997
#
# ValueError: Wrong number of columns at line 2236

# %% [markdown]
# # Installation of resources

# %%
# !pip3.9 install ipympl

# %%
# !pip3.9 install matplotlib

# %%
# !pip3.9 install --user scipy

# %%
# !pip3.9 install pyproj

# %%
# !pip3.9 install basemap

# %%
# !pip3.9 install basemap-data-hires
